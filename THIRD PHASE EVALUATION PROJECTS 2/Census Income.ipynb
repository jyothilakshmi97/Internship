# %%
#Import basic libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset
df = pd.read_csv("census_income.csv")
df
# Out:
#        Age          Workclass  Final Weight    Education  EducationNum  \
# 0       39          State-gov         77516    Bachelors            13
# 1       50   Self-emp-not-inc         83311    Bachelors            13
# 2       38            Private        215646      HS-grad             9
# 3       53            Private        234721         11th             7
# 4       28            Private        338409    Bachelors            13
# ...    ...                ...           ...          ...           ...
# 32556   27            Private        257302   Assoc-acdm            12
# 32557   40            Private        154374      HS-grad             9
# 32558   58            Private        151910      HS-grad             9
# 32559   22            Private        201490      HS-grad             9
# 32560   52       Self-emp-inc        287927      HS-grad             9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
#DETERMINE THE SHAPE OF THE DATASET
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# # There are 32561 rows and 15 colums.Here 'income' is target variable and others are independent variable

# %%
#first 5 records
df.head()
# Out:
#    Age          Workclass  Final Weight   Education  EducationNum  \
# 0   39          State-gov         77516   Bachelors            13
# 1   50   Self-emp-not-inc         83311   Bachelors            13
# 2   38            Private        215646     HS-grad             9
# 3   53            Private        234721        11th             7
# 4   28            Private        338409   Bachelors            13
#
#         Marital Status          Occupation    Relationship    Race   Gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  capital loss  Hours per Week  Native Country  Income
# ...

# %%
#print the columns
df.columns
# Out:
# Index(['Age', 'Workclass', 'Final Weight', 'Education', 'EducationNum',
#        'Marital Status', 'Occupation', 'Relationship', 'Race', 'Gender',
#        'Capital Gain', 'capital loss', 'Hours per Week', 'Native Country',
#        'Income'],
#       dtype='object')

# %%
#iformation about the dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   Workclass       32561 non-null  object
#  2   Final Weight    32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   EducationNum    32561 non-null  int64
#  5   Marital Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Race            32561 non-null  object
#  9   Gender          32561 non-null  object
#  10  Capital Gain    32561 non-null  int64
#  11  capital loss    32561 non-null  int64
#  12  Hours per Week  32561 non-null  int64
#  13  Native Country  32561 non-null  object
#  14  Income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#to check for null values
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Final Weight      0
# Education         0
# EducationNum      0
# Marital Status    0
# Occupation        0
# Relationship      0
# Race              0
# Gender            0
# Capital Gain      0
# capital loss      0
# Hours per Week    0
# Native Country    0
# Income            0
# dtype: int64

# %% [markdown]
# # no null values present in the dataset

# %%
#to know data types
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Final Weight       int64
# Education         object
# EducationNum       int64
# Marital Status    object
# Occupation        object
# Relationship      object
# Race              object
# Gender            object
# Capital Gain       int64
# capital loss       int64
# Hours per Week     int64
# Native Country    object
# Income            object
# dtype: object

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 121124    12
#           ..
# 232784     1
# 325573     1
# 140176     1
# 318264     1
# 257302     1
# Name: Final Weight, Length: 21648, dtype: int64
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
# ...

# %%
#check how many question mark (" ?") inside dataset.
df.isin(['?']).sum().any()
# Out:
# False

# %%
#statistical summary of the data set'
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32561.0      38.581647      13.640433     17.0      28.0
# Final Weight    32561.0  189778.366512  105549.977697  12285.0  117827.0
# EducationNum    32561.0      10.080679       2.572720      1.0       9.0
# Capital Gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital loss    32561.0      87.303830     402.960219      0.0       0.0
# Hours per Week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Final Weight    178356.0  237051.0  1484705.0
# EducationNum        10.0      12.0       16.0
# Capital Gain         0.0       0.0    99999.0
# capital loss         0.0       0.0     4356.0
# Hours per Week      40.0      45.0       99.0

# %% [markdown]
# the min age of people in the dataset is 17 and max is 90.average of age is 38.

# %% [markdown]
# the min and max year of education is 1 and 16,whereas the mean education is 10.

# %% [markdown]
# # lets check in which column unique symbol "?" is preset

# %%
df['EducationNum'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %% [markdown]
# "?" not present in EducationNum

# %%
df['Education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %% [markdown]
# # "?" not present in Education

# %%
df['Native Country'].unique()

# %% [markdown]
# Here in Native Country column there are null values present in the form of question mark(?).we have to drop that.

# %%
#drop the null value in the column
df.drop(df[df['Native Country'] == ' ?'].index,inplace=True)

# %%
df['Native Country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Transport-moving',
#        ' Farming-fishing', ' Machine-op-inspct', ' Tech-support',
#        ' Craft-repair', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %% [markdown]
# Here in Occupation column there are null values present in the form of question mark(?).we have to drop that.

# %%
#drop the null value in the column
df.drop(df[df['Occupation'] == ' ?'].index,inplace=True)

# %%
df['Occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Transport-moving',
#        ' Farming-fishing', ' Machine-op-inspct', ' Tech-support',
#        ' Craft-repair', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
#TO CHECK WHETHER DUPLICATE VALUES PRESENT OR NOT
df.duplicated().sum()
# Out:
# 23

# %%
df.drop_duplicates()
# Out:
#        Age          Workclass  Final Weight    Education  EducationNum  \
# 0       39          State-gov         77516    Bachelors            13
# 1       50   Self-emp-not-inc         83311    Bachelors            13
# 2       38            Private        215646      HS-grad             9
# 3       53            Private        234721         11th             7
# 4       28            Private        338409    Bachelors            13
# ...    ...                ...           ...          ...           ...
# 32556   27            Private        257302   Assoc-acdm            12
# 32557   40            Private        154374      HS-grad             9
# 32558   58            Private        151910      HS-grad             9
# 32559   22            Private        201490      HS-grad             9
# 32560   52       Self-emp-inc        287927      HS-grad             9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %% [markdown]
# # Lets plot via graphs

# %%
df['Age'].value_counts()
# Out:
# 36    852
# 31    851
# 33    837
# 34    836
# 37    828
#      ...
# 82      7
# 83      5
# 88      3
# 85      3
# 86      1
# Name: Age, Length: 72, dtype: int64

# %%
sns.histplot(x=df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
df['Workclass'].value_counts()
# Out:
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: Workclass, dtype: int64

# %%
sns.histplot(x=df['Workclass'])
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='Count'>

# %%
df['Final Weight'].value_counts()
# Out:
# 203488    13
# 123011    12
# 113364    12
# 164190    12
# 121124    12
#           ..
# 275818     1
# 318082     1
# 138342     1
# 158040     1
# 201490     1
# Name: Final Weight, Length: 20263, dtype: int64

# %%
sns.histplot(x=df['Final Weight'])
# Out:
# <AxesSubplot:xlabel='Final Weight', ylabel='Count'>

# %%
df['Capital Gain'].value_counts()
# Out:
# 0        27624
# 15024      337
# 7688       270
# 7298       240
# 99999      148
#          ...
# 1639         1
# 6097         1
# 2538         1
# 1455         1
# 1086         1
# Name: Capital Gain, Length: 118, dtype: int64

# %%
sns.histplot(x=df['Capital Gain'])
# Out:
# <AxesSubplot:xlabel='Capital Gain', ylabel='Count'>

# %%
df['capital loss'].value_counts()
# Out:
# 0       28735
# 1902      194
# 1977      162
# 1887      155
# 1848       50
#         ...
# 2080        1
# 4356        1
# 1539        1
# 1844        1
# 1411        1
# Name: capital loss, Length: 90, dtype: int64

# %%
sns.histplot(x=df['capital loss'])
# Out:
# <AxesSubplot:xlabel='capital loss', ylabel='Count'>

# %%
df['Education'].value_counts()
# Out:
#  HS-grad         9840
#  Some-college    6678
#  Bachelors       5044
#  Masters         1627
#  Assoc-voc       1307
#  11th            1048
#  Assoc-acdm      1008
#  10th             820
#  7th-8th          557
#  Prof-school      542
#  9th              455
#  12th             377
#  Doctorate        375
#  5th-6th          288
#  1st-4th          151
#  Preschool         45
# Name: Education, dtype: int64

# %%
sns.histplot(x=df['Education'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
df['EducationNum'].value_counts()
# Out:
# 9     9840
# 10    6678
# 13    5044
# 14    1627
# 11    1307
# 7     1048
# 12    1008
# 6      820
# 4      557
# 15     542
# 5      455
# 8      377
# 16     375
# 3      288
# 2      151
# 1       45
# Name: EducationNum, dtype: int64

# %%
sns.histplot(x=df['EducationNum'])
# Out:
# <AxesSubplot:xlabel='EducationNum', ylabel='Count'>

# %%
df['Relationship'].value_counts()
# Out:
#  Husband           12463
#  Not-in-family      7726
#  Own-child          4466
#  Unmarried          3212
#  Wife               1406
#  Other-relative      889
# Name: Relationship, dtype: int64

# %%
sns.histplot(x=df['Relationship'])
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='Count'>

# %%
df['Marital Status'].value_counts()
# Out:
#  Married-civ-spouse       14065
#  Never-married             9726
#  Divorced                  4214
#  Separated                  939
#  Widowed                    827
#  Married-spouse-absent      370
#  Married-AF-spouse           21
# Name: Marital Status, dtype: int64

# %%
sns.histplot(x=df['Marital Status'])
# Out:
# <AxesSubplot:xlabel='Marital Status', ylabel='Count'>

# %%
df['Race'].value_counts()
# Out:
#  White                 25933
#  Black                  2817
#  Asian-Pac-Islander      895
#  Amer-Indian-Eskimo      286
#  Other                   231
# Name: Race, dtype: int64

# %%
sns.histplot(x=df['Race'])
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Count'>

# %%
df['Gender'].value_counts()
# Out:
#  Male      20380
#  Female     9782
# Name: Gender, dtype: int64

# %%
sns.histplot(x=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
df['Hours per Week'].value_counts()
# Out:
# 40    14251
# 50     2718
# 45     1753
# 60     1405
# 35     1184
#       ...
# 82        1
# 94        1
# 92        1
# 87        1
# 74        1
# Name: Hours per Week, Length: 94, dtype: int64

# %%
sns.histplot(x=df['Hours per Week'])
# Out:
# <AxesSubplot:xlabel='Hours per Week', ylabel='Count'>

# %%
df['Income'].value_counts()
# Out:
#  <=50K    22654
#  >50K      7508
# Name: Income, dtype: int64

# %%
sns.histplot(x=df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Count'>

# %% [markdown]
# 75.9 % population (24697 peoples) have income less than 50K. Our task is to predict income and we see that target variable income is imbalanced

# %%
df['Native Country'].value_counts()
# Out:
#  United-States                 27504
#  Mexico                          610
#  Philippines                     188
#  Germany                         128
#  Puerto-Rico                     109
#  Canada                          107
#  India                           100
#  El-Salvador                     100
#  Cuba                             92
#  England                          86
#  Jamaica                          80
#  South                            71
#  China                            68
#  Italy                            68
#  Dominican-Republic               67
#  Vietnam                          64
#  Guatemala                        63
#  Japan                            59
#  Poland                           56
#  Columbia                         56
#  Iran                             42
#  Taiwan                           42
#  Haiti                            42
#  Portugal                         34
#  Nicaragua                        33
# ...

# %%
sns.histplot(x=df['Native Country'])
# Out:
# <AxesSubplot:xlabel='Native Country', ylabel='Count'>

# %%
# Heatmap of missing value
sns.heatmap(df.isnull(),cmap="cool_r")
plt.show()

# %% [markdown]
# # EDUCATION VS INCOME

# %%
sns.scatterplot(data=df,y="Education",x="Age",hue='Income')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Education'>

# %%
plt.figure(figsize=(20,16))
sns.countplot(x='Education',hue='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
#  People having bachelors degree earns>50 k when compared to others.
#
# Also here are very handful people who earn more than 50 K having education below 12th level

# %% [markdown]
# # OCCUPATION VS INCOME

# %%
sns.scatterplot(data=df,y="Occupation",x="Age",hue='Income')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Occupation'>

# %%
plt.figure(figsize=(20,16))
plt.xticks(size=20,rotation=100)
sns.countplot(x='Occupation',hue='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %% [markdown]
# Exec-managerial role are equally likely to earn more than 50K dollars an year. Peoples working in Arm- Forces, Farming-fishing, Machine-op-inspect, Other-service, Adm-clerical, Handlers-cleaners are very less likely to earn more than 50K dollars an year. Around 25% of the people working in Sales earn more than 50K dollars an year

# %% [markdown]
# # RELATIONSHIP VS INCOME

# %%
sns.scatterplot(data=df,y="Relationship",x="Age",hue='Income')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Relationship'>

# %%
plt.figure(figsize=(20,16))
sns.countplot(df['Relationship'],hue=df['Income'],data=df)
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='count'>

# %% [markdown]
# Husbands are more likely to earn above 50 k. Wives are equally likely to earn more than 50K.Also there are handful of Unmarried people earning more than 50K dollars

# %% [markdown]
# # RACE VS INCOME

# %%
sns.scatterplot(data=df,y="Race",x="Age",hue='Income')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Race'>

# %%
plt.figure(figsize=(20,16))
sns.countplot(x=df['Race'],hue=df['Income'],data=df)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %% [markdown]
#  Maximum people earn >50 k are under White than other races.

# %% [markdown]
# # GENDER VS INCOME

# %%
sns.scatterplot(data=df,y='Age',x="Gender",hue='Income')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
plt.figure(figsize=(20,16))
sns.countplot(df['Gender'],hue=df['Income'] ,data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Men earning more than 50K than women dollars an year.A lot of gap between the earnings of men and women

# %%
sns.scatterplot(data=df,y="Age",x="Income")
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Age'>

# %%
plt.figure(figsize=(20,16))
sns.countplot(x='Age',hue='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
#  We can find maximum people earning more than 50K dollors belong to age group 30-50

# %%
sns.scatterplot(data=df,y="Marital Status",x="Age",hue='Income')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Marital Status'>

# %%
sns.scatterplot(data=df,y="Capital Gain",x="Relationship",hue='Income')
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='Capital Gain'>

# %%
sns.scatterplot(data=df,y="Capital Gain",x="Race",hue='Income')
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Capital Gain'>

# %%
sns.scatterplot(data=df,y="capital loss",x="Race",hue='Income')
# Out:
# <AxesSubplot:xlabel='Race', ylabel='capital loss'>

# %%
sns.scatterplot(data=df,y="Hours per Week",x="Age",hue='Income')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Hours per Week'>

# %%
sns.scatterplot(data=df,y="Education",x="Hours per Week",hue='Income')
# Out:
# <AxesSubplot:xlabel='Hours per Week', ylabel='Education'>

# %%
plt.figure(figsize=(20,16))
sns.barplot(x='Hours per Week',y='Income',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Hours per Week', ylabel='Income'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
catgorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        catgorical_col.append(i)
        
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)

# %%
plt.figure (figsize=(15,15))
plotnumber=1
for column in numerical_col:
    if plotnumber<=12:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
plt.figure (figsize=(15,15))
i=1
for column in numerical_col:
    if i<=12:
        plt.subplot(4,4,i)
        ax=sns.boxplot(data=df[column])
        plt.xlabel(column,fontsize=15)
    i+=1
plt.show()

# %%
catgorical_col
# Out:
# ['Workclass',
#  'Education',
#  'Marital Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Gender',
#  'Native Country',
#  'Income']

# %%
numerical_col
# Out:
# ['Age',
#  'Final Weight',
#  'EducationNum',
#  'Capital Gain',
#  'capital loss',
#  'Hours per Week']

# %% [markdown]
# # encoding process

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in catgorical_col:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Age  Workclass  Final Weight  Education  EducationNum  Marital Status  \
# 0   39          5         77516          9            13               4
# 1   50          4         83311          9            13               2
# 2   38          2        215646         11             9               0
# 3   53          2        234721          1             7               2
# 4   28          2        338409          9            13               2
#
#    Occupation  Relationship  Race  Gender  Capital Gain  capital loss  \
# 0           0             1     4       1          2174             0
# 1           3             0     4       1             0             0
# 2           5             1     4       1             0             0
# 3           5             0     2       1             0             0
# 4           9             5     2       0             0             0
#
#    Hours per Week  Native Country  Income
# 0              40              38       0
# ...

# %%
df.dtypes
# Out:
# Age               int64
# Workclass         int32
# Final Weight      int64
# Education         int32
# EducationNum      int64
# Marital Status    int32
# Occupation        int32
# Relationship      int32
# Race              int32
# Gender            int32
# Capital Gain      int64
# capital loss      int64
# Hours per Week    int64
# Native Country    int32
# Income            int32
# dtype: object

# %%
le = LabelEncoder() # label encoder 
df['Income']=le.fit_transform(df['Income']) 
df['Gender']=le.fit_transform(df['Gender'])

# %%
df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %%
df.Income.value_counts()
# Out:
# 0    22654
# 1     7508
# Name: Income, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
# Splitting data in target and dependent feature
X = df.drop(['Income'], axis =1)
Y = df['Income']

# %%
# Oversampleing using SMOTE 
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)
Y.value_counts()
# Out:
# 0    22654
# 1    22654
# Name: Income, dtype: int64

# %%
threshold=3
print(np.where(z>threshold))
# Out:
# (array([    4,    10,    11, ..., 30137, 30152, 30154], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
print(df.shape)
print(df1.shape)
# Out:
# (30162, 15)
# (25760, 15)

# %% [markdown]
# # Percent of data loss

# %%
loss_percent = (30162-25760)/30162*100
loss_percent
# Out:
# 14.594522909621377

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA()
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt = PowerTransformer(method='yeo-johnson')
transformed_data = pt.fit_transform(x)

# %%
df.skew()
# Out:
# Age                0.530228
# Workclass          1.154858
# Final Weight       1.459220
# Education         -0.944948
# EducationNum      -0.305379
# Marital Status    -0.009453
# Occupation         0.110450
# Relationship       0.820311
# Race              -2.507036
# Gender            -0.750636
# Capital Gain      11.902682
# capital loss       4.526380
# Hours per Week     0.330869
# Native Country    -4.178907
# Income             1.161408
# dtype: float64

# %%
columns=df[['Final Weight','Relationship','Capital Gain','capital loss']]
for column in columns:
    df[column]=np.cbrt(df[column])

# %%
df.skew()
# Out:
# Age               0.530228
# Workclass         1.154858
# Final Weight     -0.161035
# Education        -0.944948
# EducationNum     -0.305379
# Marital Status   -0.009453
# Occupation        0.110450
# Relationship     -0.070744
# Race             -2.507036
# Gender           -0.750636
# Capital Gain      4.053959
# capital loss      4.300058
# Hours per Week    0.330869
# Native Country   -4.178907
# Income            1.161408
# dtype: float64

# %%
 plt.figure(figsize=(15,15))
plotnumber =1
for column in numerical_col:
    if plotnumber<=12:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
    
plt.show()

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y=SM.fit_resample(x,y)
y.value_counts()
# Out:
# 0    22654
# 1    22654
# Name: Income, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled, i) for i in range(x.shape[1])]
vif ['features'] =x.columns 
vif
# Out:
#          vif        features
# 0   1.160995             Age
# 1   1.008674       Workclass
# 2   1.012419    Final Weight
# 3   1.094917       Education
# 4   1.171166    EducationNum
# 5   1.137050  Marital Status
# 6   1.017617      Occupation
# 7   1.738459    Relationship
# 8   1.037277            Race
# 9   1.570895          Gender
# 10  1.034585    Capital Gain
# 11  1.020277    capital loss
# 12  1.145231  Hours per Week
# 13  1.033199  Native Country

# %%
pca_new = PCA(n_components=9)
x_new = pca_new.fit_transform(X_scale)
principle_x=pd.DataFrame(x_new,columns=np.arange(9))

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import classification_report ,confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (31715, 9)
# Training target vector size: (31715,)
# Test feature matrix size: (13593, 9)
# Test target vector size: (13593,)

# %%
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.7758405061428677 on Random_state 126

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=28, test_size=.3)

# %% [markdown]
# # Logistic Regression

# %%
LR= LogisticRegression()
LR.fit(X_train, Y_train)
predLR= LR.predict (X_test)
print('Accuracy score',(accuracy_score(Y_test, predLR)))
print('\n')
print(confusion_matrix(Y_test, predLR))
# Out:
# Accuracy score 0.7660560582652836
#
#
# [[5060 1772]
#  [1408 5353]]

# %% [markdown]
# # RandomForest Classifier

# %%
Rnd= RandomForestClassifier()
Rnd.fit(X_train, Y_train)
predRnd= Rnd.predict (X_test)
print('Accuracy score',(accuracy_score(Y_test, predRnd)))
print('\n')
print(confusion_matrix(Y_test, predRnd))
# Out:
# Accuracy score 0.8338850879128964
#
#
# [[5515 1317]
#  [ 941 5820]]

# %% [markdown]
# # ExtraTrees Classifier

# %%
Etr= ExtraTreesClassifier()
Etr.fit(X_train, Y_train)
predEtr= Etr.predict (X_test)
print('Accuracy score',(accuracy_score(Y_test, predEtr)))
print('\n')
print(confusion_matrix(Y_test, predEtr))
# Out:
# Accuracy score 0.8383726918266755
#
#
# [[5521 1311]
#  [ 886 5875]]

# %% [markdown]
# # SVC

# %%
svc=SVC()
svc.fit(X_train, Y_train)
predsvc=svc.predict (X_test)
print('Accuracy score',(accuracy_score(Y_test, predsvc)))
print('\n')
print(confusion_matrix(Y_test, predsvc))
# Out:
# Accuracy score 0.8179209887442066
#
#
# [[5191 1641]
#  [ 834 5927]]

# %% [markdown]
# # Gradient Boosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train, Y_train)
predgbc =gbc.predict (X_test)
print('Accuracy score',(accuracy_score(Y_test, predgbc)))
print('\n')
print(confusion_matrix(Y_test, predgbc))
# Out:
# Accuracy score 0.8040903406164938
#
#
# [[5241 1591]
#  [1072 5689]]

# %% [markdown]
# # AdaBoost Classifier

# %%
adaboost= AdaBoostClassifier()
adaboost.fit(X_train, Y_train)
predadaboost =adaboost.predict (X_test)
print('Accuracy score',(accuracy_score(Y_test, predadaboost)))
print('\n')
print(confusion_matrix(Y_test, predadaboost))
# Out:
# Accuracy score 0.7816523210475981
#
#
# [[5148 1684]
#  [1284 5477]]

# %% [markdown]
# # Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train, Y_train)
predbagging =bagging.predict (X_test)
print('Accuracy score',(accuracy_score(Y_test, predbagging)))
print('\n')
print(confusion_matrix(Y_test, predbagging))
# Out:
# Accuracy score 0.8128448466122269
#
#
# [[5592 1240]
#  [1304 5457]]

# %% [markdown]
# # Cross Validation Score

# %%
print('LogisticRegression ')
print('\n')

score=cross_val_score(LR, X, Y)
print(score)
print(score.mean())
print('Accuracy Score : ', accuracy_score(Y_test, predLR))
print('Difference between Accuracy score  and cross validation score is - ', accuracy_score(Y_test,predLR)- score.mean())
# Out:
# LogisticRegression
#
#
# [0.62061355 0.66111234 0.65140146 0.65357025 0.65875731]
# 0.649090980524336
# Accuracy Score :  0.7660560582652836
# Difference between Accuracy score  and cross validation score is -  0.11696507774094755

# %%
print(' RandomForestClassifie')
print('\n')

score=cross_val_score(Rnd, X, Y)
print(score)
print(score.mean())
print('Accuracy Score : ', accuracy_score(Y_test,predRnd))
print('Difference between Accuracy score  and cross validation score is - ', accuracy_score(Y_test,predRnd)- score.mean())
# Out:
#  RandomForestClassifie
#
#
# [0.78040168 0.84903995 0.92683734 0.93102307 0.92451164]
# 0.8823627352617345
# Accuracy Score :  0.8338850879128964
# Difference between Accuracy score  and cross validation score is -  -0.04847764734883808

# %%
print('ExtraTrees Classifier ')
print('\n')
score=cross_val_score(Etr, X, Y)
print(score)
print(score.mean())
print('Accuracy Score : ', accuracy_score(Y_test, predEtr))
print('Difference between Accuracy score  and cross validation score is - ', accuracy_score(Y_test,predEtr)- score.mean())
# Out:
# ExtraTrees Classifier
#
#
# [0.78205694 0.84274994 0.91977488 0.92660854 0.92175257]
# 0.8785885756148322
# Accuracy Score :  0.8383726918266755
# Difference between Accuracy score  and cross validation score is -  -0.04021588378815666

# %%
print('GradientBoostingClassifier ')
print('\n')
score=cross_val_score(gbc, X, Y)
print(score)
print(score.mean())
print('Accuracy Score : ', accuracy_score(Y_test, predgbc))
print('Difference between Accuracy score  and cross validation score is - ', accuracy_score(Y_test,predgbc)- score.mean())
# Out:
# GradientBoostingClassifier
#
#
# [0.78227764 0.84120503 0.90476716 0.90586028 0.90034213]
# 0.8668904480778176
# Accuracy Score :  0.8040903406164938
# Difference between Accuracy score  and cross validation score is -  -0.0628001074613238

# %%
print('AdaBoostClassifier ')
print('\n')
score=cross_val_score(adaboost, X, Y)
print(score)
print(score.mean())
print('Accuracy Score : ', accuracy_score(Y_test, predadaboost))
print('Difference between Accuracy score  and cross validation score is - ', accuracy_score(Y_test,predadaboost)- score.mean())
# Out:
# AdaBoostClassifier
#
#
# [0.78536747 0.8313838  0.88026926 0.87705551 0.87120627]
# 0.8490564613061412
# Accuracy Score :  0.7816523210475981
# Difference between Accuracy score  and cross validation score is -  -0.06740414025854313

# %%
print('BaggingClassifier ')
print('\n')
score=cross_val_score(bagging, X, Y)
print(score)
print(score.mean())
print('Accuracy Score : ', accuracy_score(Y_test, predbagging))
print('Difference between Accuracy score  and cross validation score is - ', accuracy_score(Y_test,predbagging)- score.mean())
# Out:
# BaggingClassifier
#
#
# [0.75722798 0.83005959 0.91922313 0.92175257 0.91766913]
# 0.8691864802846476
# Accuracy Score :  0.8128448466122269
# Difference between Accuracy score  and cross validation score is -  -0.05634163367242073

# %%
print('SVC')
print('\n')
score=cross_val_score(svc, X, Y)
print(score)
print(score.mean())
print('Accuracy Score : ', accuracy_score(Y_test, predsvc))
print('Difference between Accuracy score  and cross validation score is - ', accuracy_score(Y_test,predsvc)- score.mean())
# Out:
# SVC

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters ={'criterion': ['gini','entropy'],
            'random_state': [10,100,850],
            'n_estimators':[50,100,200,300]}

# %%
GCV =GridSearchCV(ExtraTreesClassifier(),parameters, cv=3)

# %%
GCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=3, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': [50, 100, 200, 300],
#                          'random_state': [10, 100, 850]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 300, 'random_state': 100}

# %%
Final_model = ExtraTreesClassifier(criterion='gini',n_estimators=100,random_state=10)
Final_model.fit(X_train, Y_train)
pred = Final_model.predict(X_test)
acc= accuracy_score(Y_test, pred)
print('Accuracy Score',(acc*100))
# Out:
# Accuracy Score 84.08739792540278

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.48      0.49      6803
#            1       0.50      0.52      0.51      6790
#
#     accuracy                           0.50     13593
#    macro avg       0.50      0.50      0.50     13593
# weighted avg       0.50      0.50      0.50     13593

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('threshold',threshold)
print('False possitive rate',fpr)
print('True possitive rate',tpr)
# Out:
# threshold [2 1 0]
# False possitive rate [0.         0.51550786 1.        ]
# True possitive rate [0.         0.52326951 1.        ]

# %%
plt.plot(fpr,tpr, color='red', label='Roc')
plt.plot([0,1],[0,1], color='blue', linestyle='--')
plt.xlabel('False possitive rate')
plt.ylabel('true possitive rate')
plt.title('receiver operating characteristic (roc) curve')
plt.legend()
plt.show()

# %%
# how  much area auc curve covered
auc_score=roc_auc_score(y_test,y_pred)
auc_score
# Out:
# 0.5038808249067974
